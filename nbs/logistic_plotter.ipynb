# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from glob import glob
import re
from collections import defaultdict

# %%
plt.style.use("default")
sns.set_theme(
    context="paper",
    style="white",
    palette="tab10",
    font="serif",
    font_scale=3,
    color_codes=True,
    rc={"text.usetex": True},
)

# %%
data_dir = "../output/logistic/"

AND_metrics = glob(data_dir + "AND/*/*metrics.txt")
NAND_metrics = glob(data_dir + "NAND/*/*metrics.txt")
NOR_metrics = glob(data_dir + "NOR/*/*metrics.txt")
OR_metrics = glob(data_dir + "OR/*/*metrics.txt")
XOR_metrics = glob(data_dir + "XOR/*/*metrics.txt")
XNOR_metrics = glob(data_dir + "XNOR/*/*metrics.txt")

# %% [markdown]
# ### Data manip

# %%
and_metric_dict = defaultdict(list)

# %%
def extract_a_and_seed(file_path):
    match = re.search(r"a(\d+\.\d+)_seed(\d+)", file_path)
    if match:
        return float(match.group(1)), int(match.group(2))
    return None, None

# %%
for path in AND_metrics:
    a, seed = extract_a_and_seed(path)
    if a is not None:
        array = np.loadtxt(path, delimiter=",")
        and_metric_dict[a].append(array)

# %%
average_AND_metric = {
    key: np.mean(and_metric_dict[key], axis=0) for key in and_metric_dict
}
std_AND_metric = {key: np.std(and_metric_dict[key], axis=0) for key in and_metric_dict}

# %%
average_AND_metric[0.1]
# Out:
# array([[0.00000000e+00, 6.46342754e-01, 7.50000000e-01],
#        [1.00000000e+02, 5.92004200e-01, 7.50000000e-01],
#        [2.00000000e+02, 5.26875854e-01, 7.50000000e-01],
#        [3.00000000e+02, 4.50832496e-01, 7.50000000e-01],
#        [4.00000000e+02, 3.73025462e-01, 8.33333333e-01],
#        [5.00000000e+02, 3.08486894e-01, 8.33333333e-01],
#        [6.00000000e+02, 2.57250095e-01, 8.33333333e-01],
#        [7.00000000e+02, 2.15136687e-01, 9.16666667e-01],
#        [8.00000000e+02, 1.79876644e-01, 9.16666667e-01],
#        [9.00000000e+02, 1.50283528e-01, 9.16666667e-01],
#        [1.00000000e+03, 1.25297071e-01, 1.00000000e+00],
#        [1.10000000e+03, 1.04030738e-01, 1.00000000e+00],
#        [1.20000000e+03, 8.58905483e-02, 1.00000000e+00],
#        [1.30000000e+03, 7.05436651e-02, 1.00000000e+00],
#        [1.40000000e+03, 5.77759858e-02, 1.00000000e+00],
#        [1.50000000e+03, 4.73540107e-02, 1.00000000e+00],
#        [1.60000000e+03, 3.89759991e-02, 1.00000000e+00],
#        [1.70000000e+03, 3.22998731e-02, 1.00000000e+00],
#        [1.80000000e+03, 2.69918765e-02, 1.00000000e+00],
#        [1.90000000e+03, 2.27595797e-02, 1.00000000e+00],
#        [2.00000000e+03, 1.93638518e-02, 1.00000000e+00],
#        [2.10000000e+03, 1.66168093e-02, 1.00000000e+00],
#        [2.20000000e+03, 1.43741424e-02, 1.00000000e+00],
#        [2.30000000e+03, 1.25260054e-02, 1.00000000e+00],
#        [2.40000000e+03, 1.09888409e-02, 1.00000000e+00],
#        [2.50000000e+03, 9.69903482e-03, 1.00000000e+00],
#        [2.60000000e+03, 8.60775860e-03, 1.00000000e+00],
#        [2.70000000e+03, 7.67725543e-03, 1.00000000e+00],
#        [2.80000000e+03, 6.87817546e-03, 1.00000000e+00],
#        [2.90000000e+03, 6.18738371e-03, 1.00000000e+00],
#        [3.00000000e+03, 5.58653280e-03, 1.00000000e+00],
#        [3.10000000e+03, 5.06102926e-03, 1.00000000e+00],
#        [3.20000000e+03, 4.59901104e-03, 1.00000000e+00],
#        [3.30000000e+03, 4.19087692e-03, 1.00000000e+00],
#        [3.40000000e+03, 3.82874974e-03, 1.00000000e+00],
#        [3.50000000e+03, 3.50615227e-03, 1.00000000e+00],
#        [3.60000000e+03, 3.21767891e-03, 1.00000000e+00],
#        [3.70000000e+03, 2.95883790e-03, 1.00000000e+00],
#        [3.80000000e+03, 2.72581288e-03, 1.00000000e+00],
#        [3.90000000e+03, 2.51543025e-03, 1.00000000e+00],
#        [4.00000000e+03, 2.32494087e-03, 1.00000000e+00],
#        [4.10000000e+03, 2.15203521e-03, 1.00000000e+00],
#        [4.20000000e+03, 1.99469709e-03, 1.00000000e+00],
#        [4.30000000e+03, 1.85119667e-03, 1.00000000e+00],
#        [4.40000000e+03, 1.72007288e-03, 1.00000000e+00],
#        [4.50000000e+03, 1.60000375e-03, 1.00000000e+00],
#        [4.60000000e+03, 1.48984499e-03, 1.00000000e+00],
#        [4.70000000e+03, 1.38860405e-03, 1.00000000e+00],
#        [4.80000000e+03, 1.29543060e-03, 1.00000000e+00],
#        [4.90000000e+03, 1.20954516e-03, 1.00000000e+00]])

# %%
a_list = list(average_AND_metric.keys())
a_list.sort()
final_mean_metric = np.array([average_AND_metric[a][-1] for a in a_list])
final_std_metric = np.array([std_AND_metric[a][-1] for a in a_list])

# %%
plt.plot(a_list, final_mean_metric[:, 1], ".", label="Loss")
# add configence interval
plt.fill_between(
    a_list,
    final_mean_metric[:, 1] - final_std_metric[:, 1],
    final_mean_metric[:, 1] + final_std_metric[:, 1],
    alpha=0.2,
)
plt.plot(a_list, final_mean_metric[:, 2], ".", label="Accuracy")
plt.fill_between(
    a_list,
    final_mean_metric[:, 2] - final_std_metric[:, 2],
    final_mean_metric[:, 2] + final_std_metric[:, 2],
    alpha=0.2,
)

# %% [markdown]
# ### All gates

# %%
# Initialize dictionaries for each gate
nand_metric_dict = defaultdict(list)
nor_metric_dict = defaultdict(list)
or_metric_dict = defaultdict(list)
xor_metric_dict = defaultdict(list)
xnor_metric_dict = defaultdict(list)


# Function to process metrics for a given gate
def process_metrics(metrics, metric_dict):
    for path in metrics:
        a, seed = extract_a_and_seed(path)
        if a is not None:
            array = np.loadtxt(path, delimiter=",")
            metric_dict[a].append(array)


# Process metrics for each gate
process_metrics(NAND_metrics, nand_metric_dict)
process_metrics(NOR_metrics, nor_metric_dict)
process_metrics(OR_metrics, or_metric_dict)
process_metrics(XOR_metrics, xor_metric_dict)
process_metrics(XNOR_metrics, xnor_metric_dict)

# Calculate average and standard deviation for each gate
average_NAND_metric = {
    key: np.mean(nand_metric_dict[key], axis=0) for key in nand_metric_dict
}
std_NAND_metric = {
    key: np.std(nand_metric_dict[key], axis=0) for key in nand_metric_dict
}

average_NOR_metric = {
    key: np.mean(nor_metric_dict[key], axis=0) for key in nor_metric_dict
}
std_NOR_metric = {key: np.std(nor_metric_dict[key], axis=0) for key in nor_metric_dict}

average_OR_metric = {
    key: np.mean(or_metric_dict[key], axis=0) for key in or_metric_dict
}
std_OR_metric = {key: np.std(or_metric_dict[key], axis=0) for key in or_metric_dict}

average_XOR_metric = {
    key: np.mean(xor_metric_dict[key], axis=0) for key in xor_metric_dict
}
std_XOR_metric = {key: np.std(xor_metric_dict[key], axis=0) for key in xor_metric_dict}

average_XNOR_metric = {
    key: np.mean(xnor_metric_dict[key], axis=0) for key in xnor_metric_dict
}
std_XNOR_metric = {
    key: np.std(xnor_metric_dict[key], axis=0) for key in xnor_metric_dict
}

# %%
# Plot final metrics for all gates
fig, ax1 = plt.subplots(figsize=(12, 8))

# Create a secondary y-axis
ax2 = ax1.twinx()

# AND gate
ax1.plot(a_list, [average_AND_metric[a][-1][1] for a in a_list], "k.", label="AND Loss")
ax1.fill_between(
    a_list,
    [average_AND_metric[a][-1][1] - std_AND_metric[a][-1][1] for a in a_list],
    [average_AND_metric[a][-1][1] + std_AND_metric[a][-1][1] for a in a_list],
    color="k",
    alpha=0.2,
)

ax2.plot(
    a_list, [average_AND_metric[a][-1][2] for a in a_list], "k.-", label="AND Accuracy"
)
ax2.fill_between(
    a_list,
    [average_AND_metric[a][-1][2] - std_AND_metric[a][-1][2] for a in a_list],
    [average_AND_metric[a][-1][2] + std_AND_metric[a][-1][2] for a in a_list],
    color="k",
    alpha=0.2,
)

# NAND gate
ax1.plot(
    a_list, [average_NAND_metric[a][-1][1] for a in a_list], "r.", label="NAND Loss"
)
ax1.fill_between(
    a_list,
    [average_NAND_metric[a][-1][1] - std_NAND_metric[a][-1][1] for a in a_list],
    [average_NAND_metric[a][-1][1] + std_NAND_metric[a][-1][1] for a in a_list],
    color="r",
    alpha=0.2,
)
ax2.plot(
    a_list,
    [average_NAND_metric[a][-1][2] for a in a_list],
    "r.-",
    label="NAND Accuracy",
)
ax2.fill_between(
    a_list,
    [average_NAND_metric[a][-1][2] - std_NAND_metric[a][-1][2] for a in a_list],
    [average_NAND_metric[a][-1][2] + std_NAND_metric[a][-1][2] for a in a_list],
    color="r",
    alpha=0.2,
)

# OR gate
ax1.plot(a_list, [average_OR_metric[a][-1][1] for a in a_list], "c.", label="OR Loss")
ax1.fill_between(
    a_list,
    [average_OR_metric[a][-1][1] - std_OR_metric[a][-1][1] for a in a_list],
    [average_OR_metric[a][-1][1] + std_OR_metric[a][-1][1] for a in a_list],
    color="c",
    alpha=0.2,
)
ax2.plot(
    a_list, [average_OR_metric[a][-1][2] for a in a_list], "c.-", label="OR Accuracy"
)
ax2.fill_between(
    a_list,
    [average_OR_metric[a][-1][2] - std_OR_metric[a][-1][2] for a in a_list],
    [average_OR_metric[a][-1][2] + std_OR_metric[a][-1][2] for a in a_list],
    color="c",
    alpha=0.2,
)

# NOR gate
ax1.plot(a_list, [average_NOR_metric[a][-1][1] for a in a_list], "b.", label="NOR Loss")
ax1.fill_between(
    a_list,
    [average_NOR_metric[a][-1][1] - std_NOR_metric[a][-1][1] for a in a_list],
    [average_NOR_metric[a][-1][1] + std_NOR_metric[a][-1][1] for a in a_list],
    color="b",
    alpha=0.2,
)
ax2.plot(
    a_list, [average_NOR_metric[a][-1][2] for a in a_list], "b.-", label="NOR Accuracy"
)
ax2.fill_between(
    a_list,
    [average_NOR_metric[a][-1][2] - std_NOR_metric[a][-1][2] for a in a_list],
    [average_NOR_metric[a][-1][2] + std_NOR_metric[a][-1][2] for a in a_list],
    color="b",
    alpha=0.2,
)


# XOR gate
ax1.plot(a_list, [average_XOR_metric[a][-1][1] for a in a_list], "m.", label="XOR Loss")
ax1.fill_between(
    a_list,
    [average_XOR_metric[a][-1][1] - std_XOR_metric[a][-1][1] for a in a_list],
    [average_XOR_metric[a][-1][1] + std_XOR_metric[a][-1][1] for a in a_list],
    color="m",
    alpha=0.2,
)
ax2.plot(
    a_list, [average_XOR_metric[a][-1][2] for a in a_list], "m.-", label="XOR Accuracy"
)
ax2.fill_between(
    a_list,
    [average_XOR_metric[a][-1][2] - std_XOR_metric[a][-1][2] for a in a_list],
    [average_XOR_metric[a][-1][2] + std_XOR_metric[a][-1][2] for a in a_list],
    color="m",
    alpha=0.2,
)

# XNOR gate
ax1.plot(
    a_list, [average_XNOR_metric[a][-1][1] for a in a_list], "g.", label="XNOR Loss"
)
ax1.fill_between(
    a_list,
    [average_XNOR_metric[a][-1][1] - std_XNOR_metric[a][-1][1] for a in a_list],
    [average_XNOR_metric[a][-1][1] + std_XNOR_metric[a][-1][1] for a in a_list],
    color="g",
    alpha=0.2,
)
ax2.plot(
    a_list,
    [average_XNOR_metric[a][-1][2] for a in a_list],
    "g.-",
    label="XNOR Accuracy",
)
ax2.fill_between(
    a_list,
    [average_XNOR_metric[a][-1][2] - std_XNOR_metric[a][-1][2] for a in a_list],
    [average_XNOR_metric[a][-1][2] + std_XNOR_metric[a][-1][2] for a in a_list],
    color="g",
    alpha=0.2,
)

# Set logarithmic scale for loss
ax1.set_yscale("log")

# Labels and title
ax1.set_xlabel("Logistic Map $a$")
ax1.set_ylabel("Loss $\\mathcal{L}$")
ax2.set_ylabel("Accuracy $\\mathcal{A}$")
# Create separate legends for loss and accuracy
loss_legend = ax1.legend(
    loc="upper left", bbox_to_anchor=(0, 1), bbox_transform=ax1.transAxes, fontsize=9
)
accuracy_legend = ax2.legend(
    loc="upper right", bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes, fontsize=9
)

# Add the legends to the figure
fig.add_artist(loss_legend)
fig.add_artist(accuracy_legend)
# plt.title("Final Metrics of All Gates with logistic sweep")
plt.savefig("../figures/logistic_sweep.png", dpi=300, bbox_inches="tight")
plt.savefig("../figures/logistic_sweep.pdf", dpi=300, bbox_inches="tight")
plt.savefig("../figures/logistic_sweep.svg", dpi=300, bbox_inches="tight")
plt.show()

# %%
# Prepare data for matrix plot
gates = ["AND", "NAND", "NOR", "OR", "XOR", "XNOR"]
metrics_dict = {
    "AND": average_AND_metric,
    "NAND": average_NAND_metric,
    "NOR": average_NOR_metric,
    "OR": average_OR_metric,
    "XOR": average_XOR_metric,
    "XNOR": average_XNOR_metric,
}

# Create a matrix of accuracies
accuracy_matrix = np.zeros((len(gates), len(a_list)))

for i, gate in enumerate(gates):
    for j, a in enumerate(a_list):
        if a in metrics_dict[gate]:
            accuracy_matrix[i, j] = metrics_dict[gate][a][-1][
                2
            ]  # Accuracy is at index 2

# Create a matrix plot
fig, ax = plt.subplots(figsize=(12, 4))

# Plot the matrix
sns.heatmap(
    accuracy_matrix,
    yticklabels=gates,
    cmap="magma",
    ax=ax,
    cbar_kws={"label": "Accuracy $\\mathcal{A}$"},
)
ax.set_xlabel("Logistic Map $a$")
ax.set_xticks(np.linspace(0, len(a_list) - 1, 5))
ax.set_xticklabels(
    [f"{a_list[int(i)]:.2f}" for i in np.linspace(0, len(a_list) - 1, 5)]
)
ax.set_ylabel("Gate $G$")
# Out:
# Text(100.44352703376877, 0.5, 'Gate $G$')

# %%
# Create a figure with 2 axes
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(24, 8))

# AND gate
ax1.plot(a_list, [average_AND_metric[a][-1][1] for a in a_list], "k.", label="AND")
ax1.fill_between(
    a_list,
    [average_AND_metric[a][-1][1] - std_AND_metric[a][-1][1] for a in a_list],
    [average_AND_metric[a][-1][1] + std_AND_metric[a][-1][1] for a in a_list],
    color="k",
    alpha=0.2,
)

# NAND gate
ax1.plot(a_list, [average_NAND_metric[a][-1][1] for a in a_list], "r.", label="NAND")
ax1.fill_between(
    a_list,
    [average_NAND_metric[a][-1][1] - std_NAND_metric[a][-1][1] for a in a_list],
    [average_NAND_metric[a][-1][1] + std_NAND_metric[a][-1][1] for a in a_list],
    color="r",
    alpha=0.2,
)

# OR gate
ax1.plot(a_list, [average_OR_metric[a][-1][1] for a in a_list], "c.", label="OR")
ax1.fill_between(
    a_list,
    [average_OR_metric[a][-1][1] - std_OR_metric[a][-1][1] for a in a_list],
    [average_OR_metric[a][-1][1] + std_OR_metric[a][-1][1] for a in a_list],
    color="c",
    alpha=0.2,
)

# NOR gate
ax1.plot(a_list, [average_NOR_metric[a][-1][1] for a in a_list], "b.", label="NOR")
ax1.fill_between(
    a_list,
    [average_NOR_metric[a][-1][1] - std_NOR_metric[a][-1][1] for a in a_list],
    [average_NOR_metric[a][-1][1] + std_NOR_metric[a][-1][1] for a in a_list],
    color="b",
    alpha=0.2,
)

# XOR gate
ax1.plot(a_list, [average_XOR_metric[a][-1][1] for a in a_list], "m.", label="XOR")
ax1.fill_between(
    a_list,
    [average_XOR_metric[a][-1][1] - std_XOR_metric[a][-1][1] for a in a_list],
    [average_XOR_metric[a][-1][1] + std_XOR_metric[a][-1][1] for a in a_list],
    color="m",
    alpha=0.2,
)

# XNOR gate
ax1.plot(a_list, [average_XNOR_metric[a][-1][1] for a in a_list], "g.", label="XNOR")
ax1.fill_between(
    a_list,
    [average_XNOR_metric[a][-1][1] - std_XNOR_metric[a][-1][1] for a in a_list],
    [average_XNOR_metric[a][-1][1] + std_XNOR_metric[a][-1][1] for a in a_list],
    color="g",
    alpha=0.2,
)

# Set logarithmic scale for loss
ax1.set_yscale("log")

# Labels and title for the first plot
ax1.set_xlabel("Logistic Map $a$")
ax1.set_ylabel("Loss $\\mathcal{L}$")
ax1.set_title("(a)")
ax1.legend(loc="upper right", fontsize=24, ncols=2)
# # Create separate legends for loss and accuracy
# loss_legend = ax1.legend(
#     loc="upper right", bbox_to_anchor=(0, 1), bbox_transform=ax1.transAxes, fontsize=16
# )
# # Add the legends to the figure
# fig.add_artist(loss_legend)

# Prepare data for matrix plot
gates = ["AND", "NAND", "NOR", "OR", "XOR", "XNOR"]
metrics_dict = {
    "AND": average_AND_metric,
    "NAND": average_NAND_metric,
    "NOR": average_NOR_metric,
    "OR": average_OR_metric,
    "XOR": average_XOR_metric,
    "XNOR": average_XNOR_metric,
}

# Create a matrix of accuracies
accuracy_matrix = np.zeros((len(gates), len(a_list)))

for i, gate in enumerate(gates):
    for j, a in enumerate(a_list):
        if a in metrics_dict[gate]:
            accuracy_matrix[i, j] = metrics_dict[gate][a][-1][
                2
            ]  # Accuracy is at index 2

# Plot the matrix
sns.heatmap(
    accuracy_matrix,
    yticklabels=gates,
    cmap="magma",
    ax=ax3,
    cbar_kws={"label": "Accuracy $\\mathcal{A}$"},
)
ax3.set_xlabel("Logistic Map $a$")
ax3.set_xticks(np.linspace(0, len(a_list) - 1, 5))
ax3.set_xticklabels(
    [f"{a_list[int(i)]:.2f}" for i in np.linspace(0, len(a_list) - 1, 5)]
)
ax3.set_ylabel("Gate $G$")
ax3.set_title("(b)")

plt.tight_layout()
plt.savefig("../figures/logistic_combined_plot.png", dpi=300, bbox_inches="tight")
plt.savefig("../figures/logistic_combined_plot.pdf", dpi=300, bbox_inches="tight")
plt.savefig("../figures/logistic_combined_plot.svg", dpi=300, bbox_inches="tight")
plt.show()
